# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression

# %%
# Load Integrated Dataset (Member 2's Output)

df = pd.read_csv("02.integrated_telco_data.csv")
print("Loaded integrated data:", df.shape)
df.head()
# Out:
# Loaded integrated data: (70000, 21)
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  CUST00001    Male            0.0      No        Yes       3          Yes
# 1  CUST00002    Male            1.0     Yes         No       2          Yes
# 2  CUST00003  Female            0.0      No         No      42          Yes
# 3  CUST00004  Female            0.0      No        Yes      40          Yes
# 4  CUST00005    Male            1.0     Yes        Yes      17          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0           Yes              No             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2           Yes             DSL             No  ...               No
# 3           Yes     Fiber optic             No  ...              Yes
# 4       Unknown     Fiber optic            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-Month               No
# 1         Yes     Unknown              No        One year              Yes
# 2     Unknown         Yes             Yes  Month-to-Month               No
# 3          No          No              No  Month-to-Month               No
# 4          No          No              No        Two year              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0               Mailed check          68.61        205.83    Yes
# 1  Bank transfer (automatic)          23.15         46.30     No
# 2           Electronic check          42.63       1790.46    Yes
# 3           Electronic check          75.04       3001.60     No
# 4           Electronic check          22.38        380.46    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Normalization

# %%
# Normalization

# Min-Max scaling for MonthlyCharges, TotalCharges
minmax = MinMaxScaler()
df[['MonthlyCharges','TotalCharges']] = minmax.fit_transform(df[['MonthlyCharges','TotalCharges']])

# Z-score scaling for tenure
zscore = StandardScaler()
df[['tenure']] = zscore.fit_transform(df[['tenure']])

df[['tenure','MonthlyCharges','TotalCharges']].head()
# Out:
#      tenure  MonthlyCharges  TotalCharges
# 0 -1.244974        0.034155      0.000306
# 1 -1.307522        0.003476      0.000069
# 2  1.194413        0.016622      0.002662
# 3  1.069316        0.038495      0.004463
# 4 -0.369296        0.002956      0.000566

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner Dependents    tenure  \
# 0      CUST00001    Male            0.0       No        Yes -1.244974
# 1      CUST00002    Male            1.0      Yes         No -1.307522
# 2      CUST00003  Female            0.0       No         No  1.194413
# 3      CUST00004  Female            0.0       No        Yes  1.069316
# 4      CUST00005    Male            1.0      Yes        Yes -0.369296
# ...          ...     ...            ...      ...        ...       ...
# 69995  CUST69996    Male            1.0      Yes        Yes  0.443833
# 69996  CUST69997    Male            0.0      Yes    Unknown -0.494393
# 69997  CUST69998    Male            0.0  Unknown         No -0.181651
# 69998  CUST69999    Male            0.0       No         No -0.119103
# 69999  CUST70000  Female            0.0       No         No -1.244974
#
#       PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0              Yes           Yes              No             No  ...
# 1              Yes           Yes             DSL             No  ...
# 2              Yes           Yes             DSL             No  ...
# 3              Yes           Yes     Fiber optic             No  ...
# 4              Yes       Unknown     Fiber optic            Yes  ...
# ...            ...           ...             ...            ...  ...
# 69995          Yes           Yes     Fiber optic            Yes  ...
# 69996          Yes           Yes     Fiber optic             No  ...
# 69997          Yes            No             DSL            Yes  ...
# 69998          Yes            No     Fiber optic             No  ...
# 69999          Yes           Yes              No             No  ...
#
#       DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0                   No          No          No              No
# 1                   No         Yes     Unknown              No
# 2                   No     Unknown         Yes             Yes
# 3                  Yes          No          No              No
# 4                  Yes          No          No              No
# ...                ...         ...         ...             ...
# 69995               No         Yes          No              No
# 69996               No          No          No              No
# 69997               No          No     Unknown              No
# 69998               No          No         Yes              No
# 69999               No          No          No              No
#
#              Contract PaperlessBilling              PaymentMethod  \
# 0      Month-to-Month               No               Mailed check
# 1            One year              Yes  Bank transfer (automatic)
# 2      Month-to-Month               No           Electronic check
# 3      Month-to-Month               No           Electronic check
# 4            Two year              Yes           Electronic check
# ...               ...              ...                        ...
# 69995        Two year               No           Electronic check
# 69996  Month-to-Month              Yes  Bank transfer (automatic)
# 69997  Month-to-Month              Yes               Mailed check
# 69998  Month-to-Month              Yes           Electronic check
# 69999  Month-to-Month               No           Electronic check
#
#       MonthlyCharges  TotalCharges  Churn
# 0           0.034155      0.000306    Yes
# 1           0.003476      0.000069     No
# 2           0.016622      0.002662    Yes
# 3           0.038495      0.004463     No
# 4           0.002956      0.000566    Yes
# ...              ...           ...    ...
# 69995       0.038366      0.003339     No
# 69996       0.015299      0.000907    Yes
# 69997       0.007720      0.000876     No
# 69998       0.019416      0.001460     No
# 69999       0.036720      0.000323    Yes
#
# [70000 rows x 21 columns]

# %%
import pickle

# --- 1. Save the Z-Score Scaler (for 'tenure') ---
zscore_filename = 'tenure_zscore_scaler.pkl'
with open(zscore_filename, 'wb') as f:
    pickle.dump(zscore, f)
print(f"Z-score scaler saved as {zscore_filename}")

# --- 2. Save the Min-Max Scaler (for 'MonthlyCharges' & 'TotalCharges') ---
minmax_filename = 'charges_minmax_scaler.pkl'
with open(minmax_filename, 'wb') as f:
    pickle.dump(minmax, f)
print(f"Min-Max scaler saved as {minmax_filename}")
# Out:
# Z-score scaler saved as tenure_zscore_scaler.pkl
# Min-Max scaler saved as charges_minmax_scaler.pkl

# %% [markdown]
# Encoding Categorical Variables

# %% [markdown]
# this is beacuse this encoding is best for MLP classifire. or other wise is it has 1,2,3 like this the classifire may get this as the count

# %%
# Encoding
# One-hot encoding for categorical
cat_cols = ['Contract','PaymentMethod','gender','Partner','Dependents','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies',]
df = pd.get_dummies(df, columns=cat_cols) # removed drop_first=True because of mlp classifier. and to avoid information loss
# and this will remove the original cat_cols columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 49 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customerID                               70000 non-null  object
#  1   SeniorCitizen                            70000 non-null  float64
#  2   tenure                                   70000 non-null  float64
#  3   PhoneService                             70000 non-null  object
#  4   PaperlessBilling                         70000 non-null  object
#  5   MonthlyCharges                           70000 non-null  float64
#  6   TotalCharges                             70000 non-null  float64
#  7   Churn                                    70000 non-null  object
#  8   Contract_Month-to-Month                  70000 non-null  bool
#  9   Contract_One year                        70000 non-null  bool
#  10  Contract_Two year                        70000 non-null  bool
#  11  PaymentMethod_Bank transfer (automatic)  70000 non-null  bool
#  12  PaymentMethod_Credit card (automatic)    70000 non-null  bool
#  13  PaymentMethod_Electronic check           70000 non-null  bool
#  14  PaymentMethod_Mailed check               70000 non-null  bool
#  15  PaymentMethod_Unknown                    70000 non-null  bool
#  16  gender_Female                            70000 non-null  bool
#  17  gender_Male                              70000 non-null  bool
#  18  gender_Unknown                           70000 non-null  bool
#  19  Partner_No                               70000 non-null  bool
#  20  Partner_Unknown                          70000 non-null  bool
#  21  Partner_Yes                              70000 non-null  bool
#  22  Dependents_No                            70000 non-null  bool
#  23  Dependents_Unknown                       70000 non-null  bool
#  24  Dependents_Yes                           70000 non-null  bool
#  25  MultipleLines_No                         70000 non-null  bool
#  26  MultipleLines_Unknown                    70000 non-null  bool
#  27  MultipleLines_Yes                        70000 non-null  bool
#  28  InternetService_DSL                      70000 non-null  bool
#  29  InternetService_Fiber optic              70000 non-null  bool
#  30  InternetService_No                       70000 non-null  bool
#  31  OnlineSecurity_No                        70000 non-null  bool
#  32  OnlineSecurity_Unknown                   70000 non-null  bool
#  33  OnlineSecurity_Yes                       70000 non-null  bool
#  34  OnlineBackup_No                          70000 non-null  bool
#  35  OnlineBackup_Unknown                     70000 non-null  bool
#  36  OnlineBackup_Yes                         70000 non-null  bool
#  37  DeviceProtection_No                      70000 non-null  bool
#  38  DeviceProtection_Unknown                 70000 non-null  bool
#  39  DeviceProtection_Yes                     70000 non-null  bool
#  40  TechSupport_No                           70000 non-null  bool
#  41  TechSupport_Unknown                      70000 non-null  bool
#  42  TechSupport_Yes                          70000 non-null  bool
#  43  StreamingTV_No                           70000 non-null  bool
#  44  StreamingTV_Unknown                      70000 non-null  bool
#  45  StreamingTV_Yes                          70000 non-null  bool
#  46  StreamingMovies_No                       70000 non-null  bool
#  47  StreamingMovies_Unknown                  70000 non-null  bool
#  48  StreamingMovies_Yes                      70000 non-null  bool
# dtypes: bool(41), float64(4), object(4)
# memory usage: 7.0+ MB

# %%
# these only have two categories so we can use label encoding
# ['PhoneService','PaperlessBilling','Churn']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encorder = LabelEncoder()
encorder.fit_transform(df['Churn'])
# Out:
# array([1, 0, 1, ..., 0, 0, 1], shape=(70000,))

# %% [markdown]
# churn
#
# Yes -> 1
# No -> 0

# %%
df['Churn'] = encorder.fit_transform(df['Churn'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 49 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customerID                               70000 non-null  object
#  1   SeniorCitizen                            70000 non-null  float64
#  2   tenure                                   70000 non-null  float64
#  3   PhoneService                             70000 non-null  object
#  4   PaperlessBilling                         70000 non-null  object
#  5   MonthlyCharges                           70000 non-null  float64
#  6   TotalCharges                             70000 non-null  float64
#  7   Churn                                    70000 non-null  int64
#  8   Contract_Month-to-Month                  70000 non-null  bool
#  9   Contract_One year                        70000 non-null  bool
#  10  Contract_Two year                        70000 non-null  bool
#  11  PaymentMethod_Bank transfer (automatic)  70000 non-null  bool
#  12  PaymentMethod_Credit card (automatic)    70000 non-null  bool
#  13  PaymentMethod_Electronic check           70000 non-null  bool
#  14  PaymentMethod_Mailed check               70000 non-null  bool
#  15  PaymentMethod_Unknown                    70000 non-null  bool
#  16  gender_Female                            70000 non-null  bool
#  17  gender_Male                              70000 non-null  bool
#  18  gender_Unknown                           70000 non-null  bool
#  19  Partner_No                               70000 non-null  bool
#  20  Partner_Unknown                          70000 non-null  bool
#  21  Partner_Yes                              70000 non-null  bool
#  22  Dependents_No                            70000 non-null  bool
#  23  Dependents_Unknown                       70000 non-null  bool
#  24  Dependents_Yes                           70000 non-null  bool
#  25  MultipleLines_No                         70000 non-null  bool
#  26  MultipleLines_Unknown                    70000 non-null  bool
#  27  MultipleLines_Yes                        70000 non-null  bool
#  28  InternetService_DSL                      70000 non-null  bool
#  29  InternetService_Fiber optic              70000 non-null  bool
#  30  InternetService_No                       70000 non-null  bool
#  31  OnlineSecurity_No                        70000 non-null  bool
#  32  OnlineSecurity_Unknown                   70000 non-null  bool
#  33  OnlineSecurity_Yes                       70000 non-null  bool
#  34  OnlineBackup_No                          70000 non-null  bool
#  35  OnlineBackup_Unknown                     70000 non-null  bool
#  36  OnlineBackup_Yes                         70000 non-null  bool
#  37  DeviceProtection_No                      70000 non-null  bool
#  38  DeviceProtection_Unknown                 70000 non-null  bool
#  39  DeviceProtection_Yes                     70000 non-null  bool
#  40  TechSupport_No                           70000 non-null  bool
#  41  TechSupport_Unknown                      70000 non-null  bool
#  42  TechSupport_Yes                          70000 non-null  bool
#  43  StreamingTV_No                           70000 non-null  bool
#  44  StreamingTV_Unknown                      70000 non-null  bool
#  45  StreamingTV_Yes                          70000 non-null  bool
#  46  StreamingMovies_No                       70000 non-null  bool
#  47  StreamingMovies_Unknown                  70000 non-null  bool
#  48  StreamingMovies_Yes                      70000 non-null  bool
# dtypes: bool(41), float64(4), int64(1), object(3)
# memory usage: 7.0+ MB

# %%
mapping = {'Yes': 1, 'No': 0}

# Convert PhoneService
df['PhoneService'] = df['PhoneService'].map(mapping).astype('bool') 

# Convert PaperlessBilling
df['PaperlessBilling'] = df['PaperlessBilling'].map(mapping).astype('bool')

# %%
df
# Out:
#       customerID  SeniorCitizen    tenure  PhoneService  PaperlessBilling  \
# 0      CUST00001            0.0 -1.244974          True             False
# 1      CUST00002            1.0 -1.307522          True              True
# 2      CUST00003            0.0  1.194413          True             False
# 3      CUST00004            0.0  1.069316          True             False
# 4      CUST00005            1.0 -0.369296          True              True
# ...          ...            ...       ...           ...               ...
# 69995  CUST69996            1.0  0.443833          True             False
# 69996  CUST69997            0.0 -0.494393          True              True
# 69997  CUST69998            0.0 -0.181651          True              True
# 69998  CUST69999            0.0 -0.119103          True              True
# 69999  CUST70000            0.0 -1.244974          True             False
#
#        MonthlyCharges  TotalCharges  Churn  Contract_Month-to-Month  \
# 0            0.034155      0.000306      1                     True
# 1            0.003476      0.000069      0                    False
# 2            0.016622      0.002662      1                     True
# 3            0.038495      0.004463      0                     True
# 4            0.002956      0.000566      1                    False
# ...               ...           ...    ...                      ...
# 69995        0.038366      0.003339      0                    False
# 69996        0.015299      0.000907      1                     True
# 69997        0.007720      0.000876      0                     True
# 69998        0.019416      0.001460      0                     True
# 69999        0.036720      0.000323      1                     True
#
#        Contract_One year  ...  DeviceProtection_Yes  TechSupport_No  \
# 0                  False  ...                 False            True
# 1                   True  ...                 False           False
# 2                  False  ...                 False           False
# 3                  False  ...                  True            True
# 4                  False  ...                  True            True
# ...                  ...  ...                   ...             ...
# 69995              False  ...                 False           False
# 69996              False  ...                 False            True
# 69997              False  ...                 False            True
# 69998              False  ...                 False            True
# 69999              False  ...                 False            True
#
#        TechSupport_Unknown  TechSupport_Yes  StreamingTV_No  \
# 0                    False            False            True
# 1                    False             True           False
# 2                     True            False           False
# 3                    False            False            True
# 4                    False            False            True
# ...                    ...              ...             ...
# 69995                False             True            True
# 69996                False            False            True
# 69997                False            False           False
# 69998                False            False           False
# 69999                False            False            True
#
#        StreamingTV_Unknown  StreamingTV_Yes  StreamingMovies_No  \
# 0                    False            False                True
# 1                     True            False                True
# 2                    False             True               False
# 3                    False            False                True
# 4                    False            False                True
# ...                    ...              ...                 ...
# 69995                False            False                True
# 69996                False            False                True
# 69997                 True            False                True
# 69998                False             True                True
# 69999                False            False                True
#
#        StreamingMovies_Unknown  StreamingMovies_Yes
# 0                        False                False
# 1                        False                False
# 2                        False                 True
# 3                        False                False
# 4                        False                False
# ...                        ...                  ...
# 69995                    False                False
# 69996                    False                False
# 69997                    False                False
# 69998                    False                False
# 69999                    False                False
#
# [70000 rows x 49 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 49 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   customerID                               70000 non-null  object
#  1   SeniorCitizen                            70000 non-null  float64
#  2   tenure                                   70000 non-null  float64
#  3   PhoneService                             70000 non-null  bool
#  4   PaperlessBilling                         70000 non-null  bool
#  5   MonthlyCharges                           70000 non-null  float64
#  6   TotalCharges                             70000 non-null  float64
#  7   Churn                                    70000 non-null  int64
#  8   Contract_Month-to-Month                  70000 non-null  bool
#  9   Contract_One year                        70000 non-null  bool
#  10  Contract_Two year                        70000 non-null  bool
#  11  PaymentMethod_Bank transfer (automatic)  70000 non-null  bool
#  12  PaymentMethod_Credit card (automatic)    70000 non-null  bool
#  13  PaymentMethod_Electronic check           70000 non-null  bool
#  14  PaymentMethod_Mailed check               70000 non-null  bool
#  15  PaymentMethod_Unknown                    70000 non-null  bool
#  16  gender_Female                            70000 non-null  bool
#  17  gender_Male                              70000 non-null  bool
#  18  gender_Unknown                           70000 non-null  bool
#  19  Partner_No                               70000 non-null  bool
#  20  Partner_Unknown                          70000 non-null  bool
#  21  Partner_Yes                              70000 non-null  bool
#  22  Dependents_No                            70000 non-null  bool
#  23  Dependents_Unknown                       70000 non-null  bool
#  24  Dependents_Yes                           70000 non-null  bool
#  25  MultipleLines_No                         70000 non-null  bool
#  26  MultipleLines_Unknown                    70000 non-null  bool
#  27  MultipleLines_Yes                        70000 non-null  bool
#  28  InternetService_DSL                      70000 non-null  bool
#  29  InternetService_Fiber optic              70000 non-null  bool
#  30  InternetService_No                       70000 non-null  bool
#  31  OnlineSecurity_No                        70000 non-null  bool
#  32  OnlineSecurity_Unknown                   70000 non-null  bool
#  33  OnlineSecurity_Yes                       70000 non-null  bool
#  34  OnlineBackup_No                          70000 non-null  bool
#  35  OnlineBackup_Unknown                     70000 non-null  bool
#  36  OnlineBackup_Yes                         70000 non-null  bool
#  37  DeviceProtection_No                      70000 non-null  bool
#  38  DeviceProtection_Unknown                 70000 non-null  bool
#  39  DeviceProtection_Yes                     70000 non-null  bool
#  40  TechSupport_No                           70000 non-null  bool
#  41  TechSupport_Unknown                      70000 non-null  bool
#  42  TechSupport_Yes                          70000 non-null  bool
#  43  StreamingTV_No                           70000 non-null  bool
#  44  StreamingTV_Unknown                      70000 non-null  bool
#  45  StreamingTV_Yes                          70000 non-null  bool
#  46  StreamingMovies_No                       70000 non-null  bool
#  47  StreamingMovies_Unknown                  70000 non-null  bool
#  48  StreamingMovies_Yes                      70000 non-null  bool
# dtypes: bool(43), float64(4), int64(1), object(1)
# memory usage: 6.1+ MB

# %%
df.to_csv("03.transformed_telco_data.csv", index=False)

print(" Data Transformation & Discretization complete. Saved as 03.transformed_telco_data.csv")
print("Final dataset shape:", df.shape)
# Out:
#  Data Transformation & Discretization complete. Saved as 03.transformed_telco_data.csv
# Final dataset shape: (70000, 49)
